# %% [markdown]
# # Lecture 8: The shooting method for BVP's
#
# **Overview:**
# * Root finding and boundary value problems.
#
# **Next Lecture:**
# * Shoot and Matching, 1D Schrodinger eqn.
#
# ---

# %% [markdown]
# ### Tasks
# - How does the solution for the launch angle depend on the initial bracketing window for your search?
# - Can you extend this code to handle the case with air resistance?
# - Does the addition of air resistance result in new complications for the root finder?

# %%
#%matplotlib notebook
import numpy as np, matplotlib.pyplot as plt
from numpy import pi
import Particle3D as pt

# %%
def bisect(f, bracket, target, v, Cd, tol = 1.e-6):
    """ find the root of a function f using bisection
    a and b are low and high bracket limits
    v is a velocity
    Cd is a drag coefficent """
    a = bracket[0]
    b = bracket[1]
    
    fa = f(a,target, v, Cd)
    fb = f(b,target, v, Cd)
    gap  = abs(a - b)
   
    if fa == None :
        return 
    if fb == None :
        return
    
    if (fa*fb > 0.0):
        print('Bisection error: no root bracketed')
        return None
    elif fa == 0.0: return a
    elif fb == 0.0: return b

    while(True):
        xmid = 0.5*(a+b)
        fmid = f(xmid, target, v, Cd)

        if (fa*fmid > 0.0):
            a, fa = xmid, fmid
        else :b = xmid

        if (fmid == 0.0 or abs (b-a) < tol*gap): break

    return xmid

# the root of ft give the total time to reach target
def ft(t,target, V,Cd):
    # when air resistance is included you must define another function 
    # to find tfo
    
    p = pt.Projectile(tf = t,z0 = 0, v0 = V[0], u0 = V[1], w0 = V[2], Cd = Cd) 
    for ii in range(p.npoints):
        p.RK4_step()

    return p.x[1] - target[0]

# the root of fy is our solution
def fy(theta, target, v0, Cd):
    # only working in two dimensions (y,z) for now,.
    V = [0, v0*np.cos(theta), v0*np.sin(theta)]
    
    # if there is no drag, tf is easy to calculate analytically
    # with drag we must integrate and use a root finder to locate tf
    
    tf = target[0]/V[1]

    # check if we can make the range
    if tf == None:
        print('Initial velocity will not cover range')
        return 
    
    nsteps = 100
    dt = tf/nsteps
    p = pt.Projectile(tf = tf, z0 = 0, v0 = V[0], u0 = V[1], w0 = V[2], dt = dt, Cd = Cd) 
    for ii in range(nsteps):
        p.RK4_step()
    
    print("y(tf) = ", p.x[2])
    return p.x[2] - target[1]

# %% [markdown]
# * Change parameters and find launch angle below

# %%
v0 = 86 #initial launch speed
xb = 35 # x coordinate of target
yb = 2 # y coordinate of target
Cd = 0.00 # drag coefficient, you must edit ft and fy above to work for non-zero Cd

theta_bracket = [0.11,1] # in radians

# find the launch angle
# it would be more efficient to first check if we bracket the root before trying a full
# bisection search
theta = None
while not theta:
    theta = bisect(fy, theta_bracket, [xb, yb], v0, Cd)
    
    if not theta:
        print("Increasing launch speed by 1 %\n")
        v0=v0*1.01

# only make a plot if we can hit our target
if (theta != None):
    print("theta = ", theta*180/pi)
    # max time for plotting purposes
    t_max = xb/(v0*np.cos(theta))

    fig = plt.figure()
    ax = fig.add_subplot(111)
    
    # plot the trajectory
    V = [0, v0*np.cos(theta), v0*np.sin(theta)]
    p = pt.Projectile(tf = t_max*2,  z0 = 0, u0 = V[0], v0 = V[1], w0 = V[2], dt = 0.001, Cd = Cd) 
    p.scipy_trajectory()
    ax.plot(p.xv[:,1], p.xv[:,2], lw = 2, label = '$v_0$ = {:.2f}, $\\theta$ = {:.1f}'.format(v0,theta*180/np.pi))

    # plot the target position
    ax.vlines(xb, 0 , yb)
    ax.plot(xb, yb, marker ='o', ls = 'None', color = 'r', label = 'Target')
    
    
    ax.set_xlabel('x (m)')
    ax.set_ylabel('y (m)')
    ax.legend()
    plt.show()
# Out:
# y(tf) =  3.0441165460520474
# y(tf) =  51.72916263956563
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.0603030915062415
# y(tf) =  51.783941744790035
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.0761706980685197
# y(tf) =  51.83764148523181
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.0917256500950847
# y(tf) =  51.890283128640604
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.1069741081154287
# y(tf) =  51.94188752370875
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.1219221112723217
# y(tf) =  51.992475108326076
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.1365755797135484
# y(tf) =  52.042065917675686
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.1509403169365737
# y(tf) =  52.09067959216775
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.165022012087103
# y(tf) =  52.13833538521956
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.1788262422120988
# y(tf) =  52.18505217087953
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.192358474468749
# y(tf) =  52.23084845130342
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2056240682896004
# y(tf) =  52.275742364080095
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2186282775052053
# y(tf) =  52.31975168941756
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2313762524249294
# y(tf) =  52.36289385718251
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2438730418766766
# y(tf) =  52.405185953806004
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2561235952064917
# y(tf) =  52.44664472904678
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2681327642387608
# y(tf) =  52.48728660262864
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2799053051977287
# y(tf) =  52.52712767074137
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.2914458805913087
# y(tf) =  52.566183712416816
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3027590610575155
# y(tf) =  52.60447019577649
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3138493271747675
# y(tf) =  52.64200228415956
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.324721071236408
# y(tf) =  52.67879484212751
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.335378598990167
# y(tf) =  52.71486244135101
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3458261313436153
# y(tf) =  52.75021936638129
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3560678060357603
# y(tf) =  52.78487962030789
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3661076792757925
# y(tf) =  52.81885693030358
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.375949727349534
# y(tf) =  52.85216475306192
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3855978481942954
# y(tf) =  52.88481628012598
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.3950558629426184
# y(tf) =  52.91682444311413
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4043275174356205
# y(tf) =  52.9482019188403
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4134164837065692
# y(tf) =  52.97896113433458
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.422326361435197
# y(tf) =  53.00911427176683
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.431060679373248
# y(tf) =  53.03867327326882
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.439622896742211
# y(tf) =  53.06764984566592
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4480164046031434
# y(tf) =  53.09605546511167
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4562445271998894
# y(tf) =  53.123901381635626
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4643105232755205
# y(tf) =  53.15119862359611
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4722175873629824
# y(tf) =  53.17795800204951
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.479968851050347
# y(tf) =  53.20419011503202
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4875673842209616
# y(tf) =  53.229905351756514
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.4950161962694213
# y(tf) =  53.255113896727146
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5023182372932866
# y(tf) =  53.27982573377279
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5094763992616067
# y(tf) =  53.304050650002665
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5164935171601446
# y(tf) =  53.3277982396799
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5233723701143154
# y(tf) =  53.35107790802337
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5301156824897317
# y(tf) =  53.37389887493195
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.536726124971289
# y(tf) =  53.39627017863605
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.543206315620775
# y(tf) =  53.418200679277255
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5495588209138638
# y(tf) =  53.439699062417404
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5557861567565117
# y(tf) =  53.460773842478126
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5618907894814216
# y(tf) =  53.48143336611404
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5678751368246955
# y(tf) =  53.501685815516865
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5737415688836096
# y(tf) =  53.52153921165744
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.579492409055074
# y(tf) =  53.54100141746096
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.585129934955915
# y(tf) =  53.56008014092338
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.5906563793249506
# y(tf) =  53.57878293816092
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.59607393090718
# y(tf) =  53.59711721640598
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6013847353206967
# y(tf) =  53.61509023693827
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6065908959064417
# y(tf) =  53.632709117961944
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6116944745612236
# y(tf) =  53.6499808374244
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6166974925543465
# y(tf) =  53.66691223577969
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.62160193132811
# y(tf) =  53.68351001869901
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6264097332826184
# y(tf) =  53.6997807597228
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6311228025449136
# y(tf) =  53.715730902870064
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.63574300572336
# y(tf) =  53.731366765184724
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6402721726465996
# y(tf) =  53.74669453924079
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6447120970885933
# y(tf) =  53.76172029559406
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.649064537478761
# y(tf) =  53.776449985186574
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.653331217598471
# y(tf) =  53.790889441703136
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.657513827263939
# y(tf) =  53.80504438388169
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6616140229951983
# y(tf) =  53.81892041777875
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6656334286723498
# y(tf) =  53.832523038989805
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.669573636178619
# y(tf) =  53.84585763482468
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6734362060308765
# y(tf) =  53.8589294864422
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.677222667997571
# y(tf) =  53.871743770940675
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.680934521704792
# y(tf) =  53.884305563410734
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.684573237229916
# y(tf) =  53.896619838942776
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.688140255684141
# y(tf) =  53.90869147459806
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.691636989782976
# y(tf) =  53.92052525134095
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.695064824405892
# y(tf) =  53.93212585593137
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.6984251171447475
# y(tf) =  53.94349788278211
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7017191988414995
# y(tf) =  53.95464583577786
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.704948374115229
# y(tf) =  53.96557413005822
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.708113921878952
# y(tf) =  53.97628709376852
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7112170958458996
# y(tf) =  53.98678896977084
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7142591250263206
# y(tf) =  53.997083917326954
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.717241214214097
# y(tf) =  54.007176013745415
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.720164544463836
# y(tf) =  54.01706925599495
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7230302735587637
# y(tf) =  54.02676756228768
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7258395364692065
# y(tf) =  54.03627477363239
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7285934458020593
# y(tf) =  54.045594655354215
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7312930922414727
# y(tf) =  54.05473089858735
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7339395449808075
# y(tf) =  54.06368712173555
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.736533852146131
# y(tf) =  54.07246687190478
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.73907704121126
# y(tf) =  54.0810736263107
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.741570119404695
# y(tf) =  54.089510793652806
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7440140741085717
# y(tf) =  54.097781715466695
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7464098732497138
# y(tf) =  54.10588966744605
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7487584656829713
# y(tf) =  54.113837860739814
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7510607815669443
# y(tf) =  54.12162944322548
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7533177327324676
# y(tf) =  54.12926750075501
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.755530213043749
# y(tf) =  54.13675505837653
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7576990987522985
# y(tf) =  54.144095081532434
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7598252488440096
# y(tf) =  54.15129047723481
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.761909505379334
# y(tf) =  54.158344095215604
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7639526938268917
# y(tf) =  54.16525872905627
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7659556233902096
# y(tf) =  54.17203711729349
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7679190873283788
# y(tf) =  54.178681944503694
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7698438632701046
# y(tf) =  54.185195842366646
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7717307135217846
# y(tf) =  54.19158139070839
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7735803853693293
# y(tf) =  54.197841118520884
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.775393611374183
# y(tf) =  54.203977504965636
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7771711096633993
# y(tf) =  54.20999298035538
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7789135842141754
# y(tf) =  54.21588992711506
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7806217251324803
# y(tf) =  54.22167068072702
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.782296208926509
# y(tf) =  54.22733753065563
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.783937698774605
# y(tf) =  54.232892721253116
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.785546844787847
# y(tf) =  54.23833845264966
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7871242842675295
# y(tf) =  54.2436768816238
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.788670641957645
# y(tf) =  54.24891012245707
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.790186530292247
# y(tf) =  54.25404024777171
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.791672549637984
# y(tf) =  54.25906928935036
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7931292885319414
# y(tf) =  54.26399923894225
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.794557323914734
# y(tf) =  54.268832049051014
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7959572213588944
# y(tf) =  54.2735696337083
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.7973295352929455
# y(tf) =  54.27821386923134
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.79867480922109
# y(tf) =  54.282766594967256
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.79999357593817
# y(tf) =  54.28722961402034
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.801286357741047
# y(tf) =  54.291604693966356
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.802553666635157
# y(tf) =  54.29589356755316
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.803796004537414
# y(tf) =  54.300097933386986
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8050138634750352
# y(tf) =  54.304219456603704
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8062077257803018
# y(tf) =  54.308259769531006
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8073780642817323
# y(tf) =  54.312220472331816
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8085253424911185
# y(tf) =  54.316103133640084
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8096500147873447
# y(tf) =  54.31990929118221
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.810752526596248
# y(tf) =  54.32364045238386
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8118333145669143
# y(tf) =  54.327298094969876
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8128928067447863
# y(tf) =  54.330883667547226
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.81393142274118
# y(tf) =  54.33439859017891
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.814949573899263
# y(tf) =  54.33784425494934
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8159476634572416
# y(tf) =  54.34122202651134
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.81692608670786
# y(tf) =  54.34453324262884
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8178852311551252
# y(tf) =  54.3477792147081
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8188254766675858
# y(tf) =  54.35096122831378
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8197471956288944
# y(tf) =  54.354080543680475
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.820650753085359
# y(tf) =  54.35713839621155
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8215365068903244
# y(tf) =  54.360135996966974
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8224048078460715
# y(tf) =  54.36307453314542
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8232559998427016
# y(tf) =  54.365955168552354
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8240904199942825
# y(tf) =  54.36877904406126
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.82490839877241
# y(tf) =  54.371547278067105
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.82571026013712
# y(tf) =  54.374260966926464
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8264963216651355
# y(tf) =  54.376921185394956
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8272668946756188
# y(tf) =  54.379528987050065
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.828022284353581
# y(tf) =  54.382085404709876
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.828762789870628
# y(tf) =  54.3845914508428
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8294887045035804
# y(tf) =  54.387048117966266
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.830200315750453
# y(tf) =  54.38945637904244
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.830897905444487
# y(tf) =  54.39181718786102
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.831581749865653
# y(tf) =  54.39413147941952
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8322521198501387
# y(tf) =  54.396400170291294
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8329092808975673
# y(tf) =  54.39862415899026
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.833553493276183
# y(tf) =  54.40080432632568
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.834185012125901
# y(tf) =  54.40294153575205
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8348040875594425
# y(tf) =  54.40503663370902
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.835410964761204
# y(tf) =  54.40709044995946
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.836005884084568
# y(tf) =  54.409103797916245
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8365890811469625
# y(tf) =  54.411077474964166
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.837160786923275
# y(tf) =  54.413012262776995
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8377212278372252
# y(tf) =  54.4149089276266
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8382706258510684
# y(tf) =  54.41676822068535
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.838809198553606
# y(tf) =  54.41859087832595
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8393371592462353
# y(tf) =  54.42037762241002
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.839854717027447
# y(tf) =  54.422129160577356
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8403620768757
# y(tf) =  54.42384618652298
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8408594397305897
# y(tf) =  54.42552938027406
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.84134700257234
# y(tf) =  54.427179408458784
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8418249584999598
# y(tf) =  54.4287969245695
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8422934968075912
# y(tf) =  54.430382569223084
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8427528030595783
# y(tf) =  54.4319369704123
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8432030591638493
# y(tf) =  54.43346074375783
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8436444434440804
# y(tf) =  54.43495449274817
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8440771307102617
# y(tf) =  54.43641880898221
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8445012923279345
# y(tf) =  54.4378542724017
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8449170962860566
# y(tf) =  54.43926145152092
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.845324707263534
# y(tf) =  54.44064090365218
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.84572428669443
# y(tf) =  54.44199317512699
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.846115992831977
# y(tf) =  54.44331880151134
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8464999808111306
# y(tf) =  54.44461830781886
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.846876402710134
# y(tf) =  54.4458922087183
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8472454076106235
# y(tf) =  54.44714100873748
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8476071416567974
# y(tf) =  54.44836520246274
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.847961748113168
# y(tf) =  54.449565274735136
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.848309367421474
# y(tf) =  54.45074170084281
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.848650137256105
# y(tf) =  54.451894946708734
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.848984192578703
# y(tf) =  54.45302546907507
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8493116656918005
# y(tf) =  54.4541337156843
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.849632686290817
# y(tf) =  54.455220125457735
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8499473815158147
# y(tf) =  54.45628512866631
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8502558760016212
# y(tf) =  54.45732914710389
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.850558291927363
# y(tf) =  54.458352594254215
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8508547490646365
# y(tf) =  54.459355875452204
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8511453648250997
# y(tf) =  54.460339388047295
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8514302543070147
# y(tf) =  54.46130352155904
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8517095303406372
# y(tf) =  54.46224865783103
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.851983303533063
# y(tf) =  54.46317517118525
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8522516823120565
# y(tf) =  54.464083428565786
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8525147729688576
# y(tf) =  54.46497378968732
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.85277267970035
# y(tf) =  54.465846607178136
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8530255046503235
# y(tf) =  54.466702226715825
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.853273347950017
# y(tf) =  54.467540987168206
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.853516307757554
# y(tf) =  54.46836322072678
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8537544802970287
# y(tf) =  54.46916925303548
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.853987959896598
# y(tf) =  54.46995940332336
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.854216839025633
# y(tf) =  54.47073398452904
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8544412083316324
# y(tf) =  54.4714933034246
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.854661156675912
# y(tf) =  54.47223766073859
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8548767711688985
# y(tf) =  54.47296735127298
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.855088137204545
# y(tf) =  54.47368266402045
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8552953384942796
# y(tf) =  54.47438388228135
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.855498457100011
# y(tf) =  54.4750712837726
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.855697573466822
# y(tf) =  54.47574514073852
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8558927664545486
# y(tf) =  54.47640572006007
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8560841133692962
# y(tf) =  54.47705328335908
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.856271689993859
# y(tf) =  54.47768808710301
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8564555706179076
# y(tf) =  54.47831038270538
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.856635828067233
# y(tf) =  54.47892041662568
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.856812533732665
# y(tf) =  54.47951843046837
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.856985757598406
# y(tf) =  54.480104661075174
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.857155568269642
# y(tf) =  54.48067934062346
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.857322032999827
# y(tf) =  54.48124269671406
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.857485217717171
# y(tf) =  54.481794952464654
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8576451870509065
# y(tf) =  54.482336326594535
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8578020043567998
# y(tf) =  54.482867033515774
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8579557317422513
# y(tf) =  54.483387283413855
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8581064300908814
# y(tf) =  54.48389728233368
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8582541590867154
# y(tf) =  54.48439723225996
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.858398977237697
# y(tf) =  54.4848873311975
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.858540941898987
# y(tf) =  54.48536777324998
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8586801092956335
# y(tf) =  54.48583874869594
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.858816534544733
# y(tf) =  54.48630044406494
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8589502716774766
# y(tf) =  54.48675304221135
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859081373660369
# y(tf) =  54.48719672238577
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859209892416271
# y(tf) =  54.48763166030853
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859335878844969
# y(tf) =  54.48805802823551
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859459382843271
# y(tf) =  54.48847599503047
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8595804533249205
# y(tf) =  54.488885726227664
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859699138239758
# y(tf) =  54.489287384102084
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859815484592914
# y(tf) =  54.489681127729455
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.859929538463266
# y(tf) =  54.490067113051985
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8600413450217737
# y(tf) =  54.49044549293873
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8601509485494083
# y(tf) =  54.49081641724669
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8602583924545284
# y(tf) =  54.491180032880344
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8603637192902758
# y(tf) =  54.49153648384963
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8604669707712302
# y(tf) =  54.4918859113267
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8605681877901175
# y(tf) =  54.49222845370222
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.860667410433862
# y(tf) =  54.492564246639475
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8607646779995237
# y(tf) =  54.49289342312932
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8608600290098947
# y(tf) =  54.49321611354181
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8609535012286793
# y(tf) =  54.493532445678255
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8610451316754557
# y(tf) =  54.493842544822016
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.861134956640447
# y(tf) =  54.49414653378758
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.861223011698753
# y(tf) =  54.49444453296976
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.861309331724555
# y(tf) =  54.494736660390764
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.861393950904864
# y(tf) =  54.49502303174715
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8614769027529925
# y(tf) =  54.495303760456814
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8615582201219927
# y(tf) =  54.49557895770158
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.861637935217604
# y(tf) =  54.4958487324737
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8617160796108854
# y(tf) =  54.49611319161675
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8617926842508816
# y(tf) =  54.49637243987009
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8618677794768694
# y(tf) =  54.49662657990888
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.861941395030222
# y(tf) =  54.496875712384366
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862013560066348
# y(tf) =  54.49711993596662
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8620843031661827
# y(tf) =  54.49735934737903
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862153652347463
# y(tf) =  54.49759404144053
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8622216350758993
# y(tf) =  54.49782411110236
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8622882782760195
# y(tf) =  54.49804964748232
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8623536083418273
# y(tf) =  54.49827073990501
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862417651147243
# y(tf) =  54.498487475933544
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862480432056377
# y(tf) =  54.49869994140585
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862541975933572
# y(tf) =  54.49890822046934
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862602307153258
# y(tf) =  54.499112395612435
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8626614496095506
# y(tf) =  54.49931254769809
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862719426725852
# y(tf) =  54.499508755997155
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8627762614638668
# y(tf) =  54.49970109821781
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862831976333038
# y(tf) =  54.499889650536915
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8628865933991796
# y(tf) =  54.50007448763047
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8629401342933543
# y(tf) =  54.50025568270282
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.862992620220408
# y(tf) =  54.50043330751621
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8630440719673036
# y(tf) =  54.50060743241958
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8630945099115594
# y(tf) =  54.50077812637389
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8631439540290304
# y(tf) =  54.500945456983125
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863192423902066
# y(tf) =  54.501109490518665
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8632399387271414
# y(tf) =  54.501270291945175
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86328651732242
# y(tf) =  54.50142792494847
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863332178135348
# y(tf) =  54.50158245195882
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8633769392499158
# y(tf) =  54.501733934176485
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86342081839366
# y(tf) =  54.50188243159635
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8634638329449285
# y(tf) =  54.5020280030302
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8635059999396195
# y(tf) =  54.50217070613151
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8635473360779184
# y(tf) =  54.502310597418244
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8635878577309892
# y(tf) =  54.50244773229391
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8636275809474023
# y(tf) =  54.50258216507045
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86366652145953
# y(tf) =  54.50271394899072
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863704694689744
# y(tf) =  54.502843136246845
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8637421157564846
# y(tf) =  54.502969778003695
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863778799480394
# y(tf) =  54.5030939244175
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8638147603900324
# y(tf) =  54.503215624656846
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8638500127276663
# y(tf) =  54.5033349269204
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863884570454994
# y(tf) =  54.50345187845794
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8639184472585613
# y(tf) =  54.503566525588404
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863951656555248
# y(tf) =  54.5036789137175
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.863984211497613
# y(tf) =  54.50378908735627
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8640161249789973
# y(tf) =  54.50389709013904
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8640474096387374
# y(tf) =  54.50400296484083
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864078077867075
# y(tf) =  54.50410675339232
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8641081418101653
# y(tf) =  54.50420849689929
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864137613374783
# y(tf) =  54.50430823565725
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864166504233166
# y(tf) =  54.50440600916767
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864194825827501
# y(tf) =  54.50450185615386
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8642225893745423
# y(tf) =  54.5045958145754
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8642498058700125
# y(tf) =  54.50468792164503
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86427648609301
# y(tf) =  54.504778213841604
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864302640610212
# y(tf) =  54.50486672692531
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8643282797801053
# y(tf) =  54.50495349595131
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8643534137570397
# y(tf) =  54.50503855528485
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8643780524953653
# y(tf) =  54.50512193861346
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8644022057531786
# y(tf) =  54.50520367896091
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8644258830964024
# y(tf) =  54.50528380870072
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864449093902441
# y(tf) =  54.50536235956828
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8644718473638817
# y(tf) =  54.50543936267336
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864494152492245
# y(tf) =  54.50551484851296
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8645160181214826
# y(tf) =  54.50558884698314
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8645374529114154
# y(tf) =  54.505661387391235
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864558465351327
# y(tf) =  54.505732498467054
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8645790637631565
# y(tf) =  54.505802208373225
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864599256304906
# y(tf) =  54.50587054471922
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8646190509737677
# y(tf) =  54.5059375345688
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8646384556095197
# y(tf) =  54.50600320445399
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864657477897246
# y(tf) =  54.50606758038355
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864676125370736
# y(tf) =  54.50613068785232
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8646944054153636
# y(tf) =  54.50619255185454
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864712325270892
# y(tf) =  54.50625319689162
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8647298920344757
# y(tf) =  54.5063126469822
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8647471126633888
# y(tf) =  54.50637092567081
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864763993977888
# y(tf) =  54.50642805603901
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8647805426638184
# y(tf) =  54.50648406071389
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864796765275263
# y(tf) =  54.50653896187494
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86481266823717
# y(tf) =  54.50659278126592
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86482825784788
# y(tf) =  54.50664554020259
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8648435402816657
# y(tf) =  54.50669725957992
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86485852159116
# y(tf) =  54.50674795988106
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864873207709646
# y(tf) =  54.506797661185786
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8648876044536253
# y(tf) =  54.5068463831787
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8649017175248255
# y(tf) =  54.50689414515573
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8649155525127763
# y(tf) =  54.506940966033135
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8649291148968152
# y(tf) =  54.50698686435426
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8649424100483305
# y(tf) =  54.50703185829743
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864955443232807
# y(tf) =  54.50707596568179
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8649682196120665
# y(tf) =  54.5071192039768
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.864980744246195
# y(tf) =  54.50716159030617
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8649930220955317
# y(tf) =  54.507203141457744
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865005058022729
# y(tf) =  54.50724387388706
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8650168567946395
# y(tf) =  54.50728380372705
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865028423084104
# y(tf) =  54.50732294679128
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8650397614719987
# y(tf) =  54.507361318582575
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865050876448831
# y(tf) =  54.507398934297726
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8650617724167264
# y(tf) =  54.50743580883494
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8650724536909937
# y(tf) =  54.507471956798085
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86508292450197
# y(tf) =  54.50750739250324
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8650931889966027
# y(tf) =  54.50754212998547
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8651032512401473
# y(tf) =  54.50757618300197
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865113115217729
# y(tf) =  54.507609565039296
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865122784835983
# y(tf) =  54.50764228931865
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8651322639245724
# y(tf) =  54.507674368800366
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8651415562376545
# y(tf) =  54.507705816189976
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865150665455465
# y(tf) =  54.50773664394152
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865159595185705
# y(tf) =  54.50776686426431
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8651683489649713
# y(tf) =  54.50779648912772
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8651769302602066
# y(tf) =  54.50782553026402
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865185342470019
# y(tf) =  54.50785399917529
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865193588926074
# y(tf) =  54.50788190713653
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865201672894364
# y(tf) =  54.50790926520065
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865209597576551
# y(tf) =  54.50793608420315
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865217366111185
# y(tf) =  54.50796237476498
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865224981574992
# y(tf) =  54.50798814729915
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865232446984075
# y(tf) =  54.508013412012325
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865239765295093
# y(tf) =  54.508038178910816
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8652469394064943
# y(tf) =  54.50806245780365
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865253972159558
# y(tf) =  54.50808625830645
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8652608663396055
# y(tf) =  54.50810958984543
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8652676246770583
# y(tf) =  54.50813246166071
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8652742498485564
# y(tf) =  54.508154882810764
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865280744478019
# ...
#
# y(tf) =  3.8656036002029115
# y(tf) =  54.50926948244968
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036053292864
# y(tf) =  54.509269499798535
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036103546283
# y(tf) =  54.50926951680552
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036152809308
# y(tf) =  54.509269533477436
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603620110186
# y(tf) =  54.50926954982034
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603624844269
# y(tf) =  54.5092695658417
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036294851015
# y(tf) =  54.509269581547635
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603634034451
# y(tf) =  54.509269596943625
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036384942056
# y(tf) =  54.509269612036675
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86560364286607
# y(tf) =  54.50926962683211
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036471517883
# y(tf) =  54.50926964133554
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036513530383
# y(tf) =  54.509269655553744
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603655471537
# y(tf) =  54.50926966949159
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036595088645
# y(tf) =  54.50926968315505
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036634666426
# y(tf) =  54.50926969654936
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603667346457
# y(tf) =  54.5092697096792
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036711498007
# y(tf) =  54.50926972255073
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036748782103
# y(tf) =  54.50926973516886
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036785331858
# y(tf) =  54.50926974753804
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603682116103
# y(tf) =  54.50926975966313
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603685628448
# y(tf) =  54.50926977154973
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036890715733
# y(tf) =  54.50926978320205
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036924468453
# y(tf) =  54.5092697946251
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603695755637
# y(tf) =  54.50926980582283
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656036989991933
# y(tf) =  54.50926981679966
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037021788716
# y(tf) =  54.50926982756037
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037052959076
# y(tf) =  54.509269838109105
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037083515056
# y(tf) =  54.50926984845005
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037113468913
# y(tf) =  54.50926985858723
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037142832593
# y(tf) =  54.509269868524726
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037171617865
# y(tf) =  54.509269878266295
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037199835627
# y(tf) =  54.509269887815854
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603722749753
# y(tf) =  54.5092698971772
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037254614684
# y(tf) =  54.50926990635441
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037281197095
# y(tf) =  54.509269915350266
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037307256055
# y(tf) =  54.5092699241692
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603733280122
# y(tf) =  54.509269932814675
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037357843207
# y(tf) =  54.509269941289304
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037382391846
# y(tf) =  54.509269949597275
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037406456796
# y(tf) =  54.50926995774146
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603743004756
# y(tf) =  54.509269965725125
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603745317345
# y(tf) =  54.50926997355145
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037475843523
# y(tf) =  54.50926998122356
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037498067124
# y(tf) =  54.50926998874452
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037519852733
# y(tf) =  54.50926999611735
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037541208983
# y(tf) =  54.50927000334457
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603756214463
# y(tf) =  54.50927001042992
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603758266746
# y(tf) =  54.50927001737505
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037602786184
# y(tf) =  54.5092700241839
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037622508537
# y(tf) =  54.509270030858495
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037641842125
# y(tf) =  54.50927003740145
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603766079468
# y(tf) =  54.50927004381548
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037679374062
# y(tf) =  54.50927005010278
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037697587187
# y(tf) =  54.50927005626666
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037715441354
# y(tf) =  54.50927006230891
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037732943935
# y(tf) =  54.50927006823222
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603775010165
# y(tf) =  54.50927007403879
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037766921
# y(tf) =  54.50927007973092
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037783409305
# y(tf) =  54.509270085310945
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603779957253
# y(tf) =  54.50927009078113
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037815417186
# y(tf) =  54.50927009614305
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037830949717
# y(tf) =  54.509270101399935
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037846176394
# y(tf) =  54.50927010655292
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603786110275
# y(tf) =  54.50927011160443
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603787573529
# y(tf) =  54.50927011655625
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603789007931
# y(tf) =  54.509270121410744
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037904140645
# y(tf) =  54.50927012616923
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603791792512
# y(tf) =  54.50927013083414
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603793143786
# y(tf) =  54.50927013540727
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037944684214
# y(tf) =  54.50927013989022
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037957669818
# y(tf) =  54.509270144284876
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037970399217
# y(tf) =  54.50927014859277
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656037982878058
# y(tf) =  54.509270152815695
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603799511105
# y(tf) =  54.50927015695574
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603800710287
# y(tf) =  54.50927016101431
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603801885842
# y(tf) =  54.509270164992785
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038030382627
# y(tf) =  54.50927016889264
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603804167949
# y(tf) =  54.5092701727157
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038052753687
# y(tf) =  54.50927017646336
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038063609826
# y(tf) =  54.509270180137456
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603807425204
# y(tf) =  54.509270183739254
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603808468445
# y(tf) =  54.5092701872695
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038094911382
# y(tf) =  54.50927019073047
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603810493676
# y(tf) =  54.5092701941234
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038114764795
# y(tf) =  54.509270197449425
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038124398906
# y(tf) =  54.509270200709715
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.86560381338435
# y(tf) =  54.50927020390594
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603814310185
# y(tf) =  54.50927020703921
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603815217753
# y(tf) =  54.50927021011112
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603816107474
# y(tf) =  54.50927021312168
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603816979655
# y(tf) =  54.509270216073546
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603817834634
# y(tf) =  54.50927021896717
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038186727746
# y(tf) =  54.50927022180352
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038194944013
# y(tf) =  54.50927022458416
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603820299831
# y(tf) =  54.50927022731001
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038210894113
# y(tf) =  54.50927022998199
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603821863414
# y(tf) =  54.50927023260157
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038226221754
# y(tf) =  54.50927023516916
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603823365982
# y(tf) =  54.50927023768656
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038240951336
# y(tf) =  54.509270240154216
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038248099387
# y(tf) =  54.509270242572974
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603825510618
# y(tf) =  54.50927024494456
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038261975367
# y(tf) =  54.5092702472689
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038268709008
# y(tf) =  54.50927024954774
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603827530975
# y(tf) =  54.50927025178182
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038281780765
# y(tf) =  54.50927025397151
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603828812403
# y(tf) =  54.509270256118384
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603829434232
# y(tf) =  54.50927025822283
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038300438342
# y(tf) =  54.50927026028592
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038306413953
# y(tf) =  54.50927026230804
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038312272054
# y(tf) =  54.509270264290656
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038318014416
# y(tf) =  54.509270266234076
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603832364386
# y(tf) =  54.509270268139346
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038329162334
# y(tf) =  54.50927027000679
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603833457229
# y(tf) =  54.509270271837394
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038339875325
# y(tf) =  54.50927027363222
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038345074113
# y(tf) =  54.509270275391465
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038350170165
# y(tf) =  54.509270277116194
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603835516606
# y(tf) =  54.50927027880694
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038360063496
# y(tf) =  54.50927028046432
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603836486444
# y(tf) =  54.50927028208924
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603836957057
# y(tf) =  54.50927028368196
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603837418426
# y(tf) =  54.509270285243005
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603837870685
# y(tf) =  54.50927028677363
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603838314044
# y(tf) =  54.509270288274045
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603838748654
# y(tf) =  54.509270289745075
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603839174714
# y(tf) =  54.50927029118691
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603839592373
# y(tf) =  54.50927029260039
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038400017976
# y(tf) =  54.509270293986006
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603840403155
# y(tf) =  54.50927029534425
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.8656038407966054
# y(tf) =  54.50927029667592
# Bisection error: no root bracketed
# Increasing launch speed by 1 %
#
# y(tf) =  3.865603841182311
